# %%
import pandas as pd

# %%
import os

os.listdir()
# Out:
# ['analysis.ipynb',
#  'classic_ml',
#  'gnn',
#  'preparation_and_eda',
#  'test.ipynb',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb']

# %%
import torch

# %%
# !pwd
# Out:
# /workspace/LBNL_FDD/notebooks

# %%
# !pip install scikit-learn tqdm
# Out:
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# ...

# %%
# !python /workspace/LBNL_FDD/scripts/train_tsai.py --model inceptiontime --dataset SDAHU --epochs 1
# Out:
# Model: inceptiontime | Device: cpu
# Traceback (most recent call last):
#   File "/workspace/LBNL_FDD/scripts/train_tsai.py", line 181, in <module>
#     main()
#   File "/workspace/LBNL_FDD/scripts/train_tsai.py", line 103, in main
#     train_df, train_target = load_split(data_dir, "train")
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/LBNL_FDD/scripts/train_tsai.py", line 70, in load_split
#     df = pd.read_csv(data_dir / f"{split}_df.csv", index_col=[0, 1])
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/.mlspace/envs/metrics_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 873, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/.mlspace/envs/metrics_env/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 300, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
# ...
